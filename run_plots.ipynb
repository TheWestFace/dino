# %%
# %load_ext nb_black

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from viz_defaults import *
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.rcParams["axes.prop_cycle"] = plt.cycler(color=color_list)

# %%
def plot_loss(curves, title="", tag=None):
    if tag == None:
        tag = title
    for path, label in curves:
        data = pd.read_json(path, lines=True)
        # plt.plot(data.epoch, data.test_acc1, label="acc")
        plt.plot(data.epoch, data.train_loss, label=label)
    plt.legend()
    plt.title(title)
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.tight_layout()
    plt.savefig(
        f"plots/pretraining_loss_{tag.replace(' ', '_').replace('=', '_').replace('/', '_')}.pdf"
    )

# %%
plot_loss(
    [
        ("pretraining_runs/patches/vit_small_p16_b17_s448_0.1_0.5_1.0_combined_PE2_scaling_default_traindataset_patches_2nodes_1gpu/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2_2nodes"),
        ("pretraining_runs/patches/vit_small_p16_b17_s448_0.1_0.5_1.0_combined_PE2_scaling_default_traindataset_patches_4nodes_1gpu/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2_4nodes"),
    ],
    "ViT-S/16-Pretraining-[ISPY2_VOLSER_uni_lateral_cropped_PE2]_0.1_0.5_1.0",
    
)

# %%
plot_loss(
    [
        ("eval_runs/vit_small_p16_0.1_0.5_1.0/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/16-Linear-Evaluation-[ISPY2_VOLSER_uni_lateral_cropped_PE2]_0.1_0.5_1.0",
    
)

# %%
plot_loss(
    [
        ("eval_runs/vit_small_p16_0.0005lr/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/16-Linear-Evaluation-[ISPY2_VOLSER_uni_lateral_cropped_PE2]",
    
)

# %%
plot_loss(
    [
        ("eval_runs/vit_small_p16_0.001lr/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/16-Linear-Evaluation",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p8/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/8",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p4/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/16",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p6/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/16",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p9/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/16",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p8/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/16",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p8/log.txt", "top 3 sequences"),
    ],
    "ViT-S/16",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p8/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_original_DCE"),
    ],
    "ViT-S/16",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p8/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE6"),
    ],
    "ViT-S/16",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_tiny_p8/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/16",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p8/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/8 ; Input Size: 512",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p8_b1/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/8-B1 ; Input Size: 720",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p8/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
        ("pretraining_runs/vit_small_p9/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/8",
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p8_b1_s1200/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2_1200"),
        ("pretraining_runs/vit_small_p8_b1_s1600/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2_1600"),
        ("pretraining_runs/vit_small_p8_b1_s3200/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2_32000"),
        ("pretraining_runs/vit_small_p8_b1_s3200_combined/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2")
    ],
    "ViT-S/8",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p8_b1_s3200_combined/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
        ("pretraining_runs/vit_small_p8_b1_s3200_combined_PE2_PE6/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2+PE6"),
        ("pretraining_runs/vit_small_p8_b1_s8000_combined_PE2/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),

    ],
    "ViT-S/8",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p8_b1_s1600_combined_PE2_scaling/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/8",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p8_b1_s1600_combined_PE2_scaling2/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/8",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p8_b1_s1600_combined_PE2_scaling2/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/8",
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p8_b1_s1600_combined_PE2_scaling_0.8_0.9_1.0_patch6_warmtmp0.07/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/8_b1_s1600_combined_PE2_scaling_0.8_0.9_1.0_patch6_warmtmp0.07",
    
)

# %%
plot_loss(
    [
        ("pretraining_runs/vit_small_p8_b1_s1600_combined_PE2_scaling_0.7_0.9_1.0/log.txt", "ISPY2_VOLSER_uni_lateral_cropped_PE2"),
    ],
    "ViT-S/8_b1_s1600_combined_PE2_scaling_0.7_0.9_1.",
    
)

# %%
plot_loss(
    [
        (
            "pretraining_runs/vit_small_p4/log.txt",
            "patch size = 4",
        ),
        (
            "pretraining_runs/vit_small_p8/log.txt",
            "patch size = 8",
        ),
        (
            "pretraining_runs/vit_small_p16/log.txt",
            "patch size = 16",
        ),
    ],
    "ViT-S/16 single view",
    tag="pretraining_loss_by_patch_size",
)

# %%
plot_loss(
    [
        (
            "pretraining_runs/vit_tiny_p8/log.txt",
            "ViT-T/8",
        ),
        (
            "pretraining_runs/vit_small_p8/log.txt",
            "ViT-S/8",
        ),
    ],
    "",
)

# %%
import torch

# %%
results = pd.DataFrame(torch.load("ft_runs/stacked_views/vit_small_p8/results.pth.tar"))
results.to_pickle("ft_runs/stacked_views/vit_small_p8/results.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /gpfs/data/huo-lab/Image/annawoodard/dino/run_plots.ipynb Cell 10' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bcri16cn407/gpfs/data/huo-lab/Image/annawoodard/dino/run_plots.ipynb#ch0000014vscode-remote?line=0'>1</a> results = pd.DataFrame(torch.load("ft_runs/stacked_views/vit_small_p8/results.pth.tar"))
#       <a href='vscode-notebook-cell://ssh-remote%2Bcri16cn407/gpfs/data/huo-lab/Image/annawoodard/dino/run_plots.ipynb#ch0000014vscode-remote?line=1'>2</a> results.to_pickle("ft_runs/stacked_views/vit_small_p8/results.pkl")
#
# NameError: name 'pd' is not defined

# %%
results[pd.isnull(results.fold)].c_index.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /gpfs/data/huo-lab/Image/annawoodard/dino/run_plots.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bcri16cn407/gpfs/data/huo-lab/Image/annawoodard/dino/run_plots.ipynb#ch0000015vscode-remote?line=0'>1</a> results[pd.isnull(results.fold)].c_index.iloc[0]
#
# NameError: name 'results' is not defined

# %%
results.c_index.mean(), results.c_index.std()
# Out:
# (0.5724790298504674, 0.02762083467602005)

# %%
results = pd.read_pickle("ft_runs/single_view/vit_small_p4/results.pkl")
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# /gpfs/data/huo-lab/Image/annawoodard/dino/run_plots.ipynb Cell 18' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bcri16cn407/gpfs/data/huo-lab/Image/annawoodard/dino/run_plots.ipynb#ch0000023vscode-remote?line=0'>1</a> results = pd.read_pickle("ft_runs/single_view/vit_small_p4/results.pkl")
#
# File ~/miniconda3/envs/maicara/lib/python3.8/site-packages/pandas/io/pickle.py:217, in read_pickle(filepath_or_buffer, compression, storage_options)
#     213         warnings.simplefilter("ignore", Warning)
#     214         # error: Argument 1 to "load" has incompatible type "Union[IO[Any],
#     215         # RawIOBase, BufferedIOBase, TextIOBase, TextIOWrapper, mmap]";
#     216         # expected "IO[bytes]"
# --> 217         return pickle.load(handles.handle)  # type: ignore[arg-type]
# ...

# %%
bmmr2_training = pd.read_csv("bmmr2_training_set_clinical.csv")

# %%
len(bmmr2_training)
# Out:
# 117

# %%
bmmr2_testing = pd.read_csv("bmmr2_testing_set_clinical.csv")

# %%
len(bmmr2_testing)
# Out:
# 74

# %%
full_clinical_data = pd.read_excel("full_ispy2_data.xlsx")

# %%
full_clinical_data[~pd.isnull(full_clinical_data.pcr)]
# Out:
#      I-SPY 2 Research ID    TCIA PATIENT ID  T0  T1  T2  T3  BMMR2_TRAIN  \
# 2                 107700  ACRIN-6698-107700   1   1   1   0            1
# 3                 373346  ACRIN-6698-373346   1   1   1   1            1
# 5                 641977  ACRIN-6698-641977   1   1   1   1            0
# 6                 326433  ACRIN-6698-326433   1   1   1   1            0
# 8                 547405  ACRIN-6698-547405   1   1   1   0            0
# ..                   ...                ...  ..  ..  ..  ..          ...
# 379               962153  ACRIN-6698-962153   1   1   1   1            0
# 380               711476  ACRIN-6698-711476   1   1   1   1            1
# 381               361701  ACRIN-6698-361701   1   1   1   1            1
# 382               924071  ACRIN-6698-924071   1   1   1   1            0
# 384               241998  ACRIN-6698-241998   1   1   1   1            1
#
#      BMMR2_TEST  PRIMARY_AIM_T0  PRIMARY_AIM_T1  ...  QC_ROI_CONFIDENCE_T3  \
# ...

# %%
74 + 117
# Out:
# 191

# %%
bmmr2_training
# Out:
#      Patient ID Number   Patient ID DICOM  analy  elig  age   race  \
# 0               107700  ACRIN-6698-107700      1     1   68  Asian
# 1               373346  ACRIN-6698-373346      1     1   59  White
# 2               949444  ACRIN-6698-949444      1     1   34  Asian
# 3               220471  ACRIN-6698-220471      1     1   50  White
# 4               220925  ACRIN-6698-220925      1     1   37  White
# ..                 ...                ...    ...   ...  ...    ...
# 112             765671  ACRIN-6698-765671      1     1   42  Black
# 113             384830  ACRIN-6698-384830      1     1   37  White
# 114             711476  ACRIN-6698-711476      1     1   47  White
# 115             361701  ACRIN-6698-361701      1     1   49  White
# 116             241998  ACRIN-6698-241998      1     1   54  Black
#
#                Ltype             hrher4g           SBRgrade  MRLD      pcr  \
# 0    Multiple masses       HR + / HER2 +         III (High)   2.3  Non-pCR
# ...

# %%
path = "ft_runs/single_view/vit_small_p4/results.pkl"
results = torch.load(path)

# %%
results
# Out:
# [{'loss': 4.362698888778686, 'c_index': 0.6386746288463133, 'fold': 3},
#  {'loss': 4.473228984408909, 'c_index': 0.5667357578041581, 'fold': 2},
#  {'loss': 4.4636251661512585, 'c_index': 0.572866833943174, 'fold': 1},
#  {'loss': 4.460675239562988, 'c_index': 0.5940518004679282, 'fold': 0},
#  {'loss': 4.390494929419623, 'c_index': 0.6268461529048994, 'fold': 4},
#  {'loss': 4.574914991855621, 'c_index': 0.5386811787058715, 'fold': None}]

# %%
results = pd.DataFrame(results)

# %%
results.c_index
# Out:
# 0    0.638675
# 1    0.566736
# 2    0.572867
# 3    0.594052
# 4    0.626846
# 5    0.538681
# Name: c_index, dtype: float64

# %%
results.to_pickle(path)
